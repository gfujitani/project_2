# %%
import pandas as pd
import csv

# %%
tsv_data = pd.read_csv('Resources/state_market_tracker.tsv000', sep='\t')
tsv_data['property_type']
# Out:
# 0        Single Family Residential
# 1                        Townhouse
# 2                      Condo/Co-op
# 3                        Townhouse
# 4        Single Family Residential
#                    ...
# 27301                    Townhouse
# 27302    Single Family Residential
# 27303    Single Family Residential
# 27304      Multi-Family (2-4 Unit)
# 27305                    Townhouse
# Name: property_type, Length: 27306, dtype: object

# %%
tsv_data['period_end'].value_counts()
tsv_data.columns
# Out:
# Index(['period_begin', 'period_end', 'period_duration', 'region_type',
#        'region_type_id', 'table_id', 'is_seasonally_adjusted', 'region',
#        'city', 'state', 'state_code', 'property_type', 'property_type_id',
#        'median_sale_price', 'median_sale_price_mom', 'median_sale_price_yoy',
#        'median_list_price', 'median_list_price_mom', 'median_list_price_yoy',
#        'median_ppsf', 'median_ppsf_mom', 'median_ppsf_yoy', 'median_list_ppsf',
#        'median_list_ppsf_mom', 'median_list_ppsf_yoy', 'homes_sold',
#        'homes_sold_mom', 'homes_sold_yoy', 'pending_sales',
#        'pending_sales_mom', 'pending_sales_yoy', 'new_listings',
#        'new_listings_mom', 'new_listings_yoy', 'inventory', 'inventory_mom',
#        'inventory_yoy', 'months_of_supply', 'months_of_supply_mom',
#        'months_of_supply_yoy', 'median_dom', 'median_dom_mom',
#        'median_dom_yoy', 'avg_sale_to_list', 'avg_sale_to_list_mom',
# ...

# %%
tsv_df=tsv_data[['period_end', 'state', 'state_code', 'property_type', 'median_sale_price', 'median_list_price', 'median_ppsf', 'homes_sold', 'pending_sales', 'inventory', 'median_dom', 'avg_sale_to_list', 'sold_above_list', 'price_drops', 'off_market_in_two_weeks', 'parent_metro_region']].copy()
tsv_df.head()
# Out:
#    period_end      state state_code              property_type  \
# 0  2019-03-31   Missouri         MO  Single Family Residential
# 1  2015-03-31    Arizona         AZ                  Townhouse
# 2  2013-12-31   Arkansas         AR                Condo/Co-op
# 3  2017-11-30    Vermont         VT                  Townhouse
# 4  2012-11-30  Louisiana         LA  Single Family Residential
#
#    median_sale_price  median_list_price  median_ppsf  homes_sold  \
# 0             185000           196900.0        116.0        4009
# 1             154100           231600.0        116.0         762
# 2             113400           142100.0         95.0          14
# 3             227400           262300.0        154.0          57
# 4             164700           169800.0         91.0        1390
#
#    pending_sales  inventory  median_dom  avg_sale_to_list  sold_above_list  \
# 0          348.0     8373.0        49.0          0.976008         0.222901
# ...

# %%
#new_tsv_df=tsv_df['period_end'].str.split('-',expand=True)
tsv_df[['Year','Month','Day']] = tsv_df['period_end'].str.split('-', expand=True)

# %%
new_columns=['period_end','Year','Month', 'state', 'state_code', 'property_type',
       'median_sale_price', 'median_list_price', 'median_ppsf', 'homes_sold',
       'pending_sales', 'inventory', 'median_dom', 'avg_sale_to_list',
       'sold_above_list', 'price_drops', 'off_market_in_two_weeks',
       'parent_metro_region']

# %%
new_tsv_df=tsv_df[['period_end','Year','Month', 'state', 'state_code', 'property_type',
       'median_sale_price', 'median_list_price', 'median_ppsf', 'homes_sold',
       'pending_sales', 'inventory', 'median_dom', 'avg_sale_to_list',
       'sold_above_list', 'price_drops', 'off_market_in_two_weeks',
       'parent_metro_region']]

# %%
new_tsv_df['state'].value_counts()
# Out:
# Missouri          605
# Nevada            605
# Massachusetts     605
# Arizona           605
# Kentucky          605
# Virginia          605
# Ohio              605
# Florida           605
# Oregon            605
# Pennsylvania      605
# Washington        605
# Columbia          605
# Illinois          605
# Colorado          605
# Oklahoma          605
# Minnesota         605
# California        605
# New York          605
# South Carolina    605
# New Hampshire     605
# Georgia           605
# Vermont           605
# North Carolina    605
# Utah              605
# Idaho             605
# Texas             605
# New Jersey        605
# Maryland          605
# Nebraska          605
# Wisconsin         604
# Louisiana         604
# Delaware          603
# Mississippi       603
# Kansas            603
# Tennessee         590
# Arkansas          589
# Hawaii            575
# New Mexico        547
# Alabama           539
# Connecticut       528
# Michigan          506
# ...

# %%
zillow_df=pd.read_csv('Resources/State_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
house_value_df=zillow_df[['RegionName','StateName','2021-01-31', '2021-02-28', '2021-03-31','2021-04-30','2021-05-31','2021-06-30','2021-07-31','2021-08-31','2021-09-30','2021-10-31','2021-11-30','2021-12-31']]
new_house_value=house_value_df.rename(columns={'RegionName':'State','StateName':'StateCode','2021-01-31':'Jan-21','2021-02-28':'Feb-21','2021-03-31':'Mar-21','2021-04-30':'Apr-21','2021-05-31':'May-21','2021-06-30':'Jun-21','2021-07-31':'Jul-21','2021-08-31':'Aug-21','2021-09-30':'Sep-21','2021-10-31':'Oct-21','2021-11-30':'Nov-21','2021-12-31':'Dec-21'})

# %%
new_house_value
# Out:
#                    State StateCode    Jan-21    Feb-21    Mar-21    Apr-21  \
# 0             California        CA  618294.0  625422.0  633308.0  643641.0
# 1                  Texas        TX  230876.0  233637.0  236573.0  240201.0
# 2               New York        NY  332201.0  335482.0  338694.0  341880.0
# 3                Florida        FL  272450.0  275593.0  279308.0  283324.0
# 4               Illinois        IL  218603.0  220648.0  222534.0  225041.0
# 5           Pennsylvania        PA  219213.0  221659.0  224161.0  226839.0
# 6                   Ohio        OH  169582.0  171645.0  174099.0  176423.0
# 7               Michigan        MI  191790.0  194264.0  196749.0  199098.0
# 8                Georgia        GA  228357.0  231539.0  234887.0  238575.0
# 9         North Carolina        NC  230321.0  233771.0  237443.0  240914.0
# 10            New Jersey        NJ  375425.0  379860.0  384130.0  389233.0
# ...
